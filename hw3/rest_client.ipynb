# %%
import requests
import pandas as pd

# %%
def get_devices(endpoint:str, host:str = "http://localhost:8080/"):
    response = requests.get(host+endpoint)
    if response.status_code == 200:
        response_dict = response.json()
        print(f"OK \n LIST OF MONITORES DEVICES: \n {response_dict}")
        return response_dict
    else:
        return 0

def retrieve_device_information(query,device:str, endpoint:str="device/", host:str="http://localhost:8080/"):
    response = requests.get(host+endpoint+device+f"?from={query[0]}&to={query[1]}")
    if response.status_code == 400 or response.status_code == 404:
        print(f"Error in handling the request: status code = {response.status_code}")
    else:
        data = response.json()
        battery_levels = data["battery_levels"]
        # power_plugged = data["power_plugged"]
        timestamps = data["timestamps"]
        return {"battery_levels":battery_levels, "timestamps":timestamps}

def delete_device_information(device:str, endpoint:str="device/", host:str="http://localhost:8080/"):
    response = requests.delete(host+endpoint+device)
    if response.status_code == 400 or response.status_code == 404:
        print(f"Error in handling the request: status code = {response.status_code}")
    else:
        print(f"Device:{device} information deletion ended successfully")

# %%
monitored_devices = get_devices(endpoint="devices")
# Out:
# OK
#  LIST OF MONITORES DEVICES:
#  {'mac_address': ['0x155d9a0cd5', '0xed9c11151d97', '0xacde48001122']}

# %%
dataframes = list()
for device in monitored_devices["mac_address"]:
    data = retrieve_device_information(device=device, query=(1674638361219, 1674638806090))
    df = pd.DataFrame(data)
    dataframes.append(df)

# %%
df_1 = dataframes[0]

# %%
DeepnoteChart(df_1, """{"layer":[{"mark":{"clip":true,"type":"trail","color":"#4c78a8","tooltip":true},"encoding":{"x":{"sort":null,"type":"quantitative","field":"timestamps","scale":{"type":"linear","zero":false}},"y":{"sort":null,"type":"quantitative","field":"battery_levels","scale":{"type":"linear","zero":false}}}}],"title":"","config":{"legend":{}},"$schema":"https://vega.github.io/schema/vega-lite/v5.json","encoding":{}}""")

# %%
df_2 = dataframes[1]

# %%
DeepnoteChart(df_2, """{"layer":[{"mark":{"clip":true,"type":"trail","color":"#4c78a8","tooltip":true},"encoding":{"x":{"sort":null,"type":"quantitative","field":"timestamps","scale":{"type":"linear","zero":false}},"y":{"sort":null,"type":"quantitative","field":"battery_levels","scale":{"type":"linear","zero":false}}}}],"title":"","config":{"legend":{}},"$schema":"https://vega.github.io/schema/vega-lite/v5.json","encoding":{}}""")

# %%
df_3 = dataframes[2]

# %%
DeepnoteChart(df_3, """{"layer":[{"mark":{"clip":true,"type":"trail","color":"#4c78a8","tooltip":true},"encoding":{"x":{"sort":null,"type":"quantitative","field":"timestamps","scale":{"type":"linear","zero":false}},"y":{"sort":null,"type":"quantitative","field":"battery_levels","scale":{"type":"linear","zero":false}}}}],"title":"","config":{"legend":{}},"$schema":"https://vega.github.io/schema/vega-lite/v5.json","encoding":{}}""")

# %%
mac_address_to_del = monitored_devices['mac_address'][-1]
delete_device_information(device=mac_address_to_del)
# Out:
# Device:0xacde48001122 information deletion ended successfully

# %%
monitored_devices = get_devices(endpoint="devices")
# Out:
# OK
#  LIST OF MONITORES DEVICES:
#  {'mac_address': ['0x155d9a0cd5', '0xed9c11151d97']}

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=4f20d7ce-f06e-4d5b-8d58-338c733410f7' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
